# %%
import pandas as pd

# %%
f = pd.read_csv("shelters.csv")

# %%
f
# Out:
#       Unnamed: 0 Report_Date        Borough  Adult_Family_Shelter  \
# 0              0  10/31/2020          Bronx                 189.0
# 1              1  10/31/2020          Bronx                 160.0
# 2              2  10/31/2020          Bronx                 258.0
# 3              3  10/31/2020          Bronx                   NaN
# 4              4  10/31/2020          Bronx                 203.0
# ...          ...         ...            ...                   ...
# 2060        2060  08/31/2021         Queens                   NaN
# 2061        2061  08/31/2021         Queens                 262.0
# 2062        2062  08/31/2021  Staten Island                   NaN
# 2063        2063  08/31/2021  Staten Island                   NaN
# 2064        2064  08/31/2021  Staten Island                   NaN
#
#       Adult_Shelter  Adult_Shelter_Commercial_Hotel  \
# 0              73.0                           140.0
# 1               0.0                             NaN
# ...

# %%
n_by_Borough_type =f.groupby(["state", "gender"])["last_name"].count()
